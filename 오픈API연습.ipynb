# %% [markdown]
# <a href="https://colab.research.google.com/github/freamwork97/TIS/blob/main/%EC%98%A4%ED%94%88API%EC%97%B0%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PublicDataReader --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from PublicDataReader import TransactionPrice
service_key='XqgThjfTjNOkhifxrGYX9%2FlaNw0VnXK9NkbiVPQ9K2so8DiPVUkDmSujK0tboohhtfxqDrUw1oELTdq8OxqDaw%3D%3D'
api = TransactionPrice(service_key)

# %%
import PublicDataReader as pdr
sigungu_name = "28260"
sigungu_name2 = "인천"
# sigungu_name3 = "청라"

code = pdr.code_bdong()
code.loc[(code['시군구코드'].str.contains(sigungu_name, na=False)) #& 
    #     (code['시도명'].str.contains(sigungu_name2, na=False)) #&
  #       (code['읍면동명'].str.contains(sigungu_name3, na=False))
  ]
# Out:
#      시도코드    시도명  시군구코드 시군구명       법정동코드 읍면동명  동리명      생성일자      말소일자
# 3478   28  인천광역시  28260   서구  2826000000  NaN  NaN  19950101       NaN
# 3479   28  인천광역시  28260   서구  2826010100  백석동  NaN  19981101       NaN
# 3480   28  인천광역시  28260   서구  2826010200  시천동  NaN  19981101       NaN
# 3481   28  인천광역시  28260   서구  2826010300  검암동  NaN  19981101       NaN
# 3482   28  인천광역시  28260   서구  2826010400  경서동  NaN  19981101       NaN
# 3483   28  인천광역시  28260   서구  2826010500  공촌동  NaN  19950101       NaN
# 3484   28  인천광역시  28260   서구  2826010600  연희동  NaN  19950101       NaN
# 3485   28  인천광역시  28260   서구  2826010700  심곡동  NaN  19950101       NaN
# 3486   28  인천광역시  28260   서구  2826010800  가정동  NaN  19950101       NaN
# 3487   28  인천광역시  28260   서구  2826010900  신현동  NaN  19981101       NaN
# 3488   28  인천광역시  28260   서구  2826011000  석남동  NaN  19950101       NaN
# 3489   28  인천광역시  28260   서구  2826011100  원창동  NaN  19981101       NaN
# ...

# %%
# 특정 년월 자료만 조회하기
df = api.get_data(
    property_type="아파트",
    trade_type="매매",
    sigungu_code="28260",
    year_month="202212",
    )
df
# 특정 기간 자료 조회하기
#df = api.get_data(
 #   property_type="아파트",
  #  trade_type="매매",
   # sigungu_code="41135",
    #start_year_month="202212",
    #end_year_month="202301",
    #)
# Out:
#       지역코드      도로명  법정동     지번             아파트  건축년도   층     전용면적     년   월  \
# 0    28260  검암로10번길  검암동  535-2      검암4차신명스카이뷰  2004   9  84.5888  2022  12
# 1    28260      검암로  검암동  501-1         풍림아이원2차  2004  16  84.9300  2022  12
# 2    28260  검암로10번길  검암동  512-2         풍림아이원3차  2004   8  84.9368  2022  12
# 3    28260  경서로31번길  경서동   1032        북청라하우스토리  2022  19  59.8661  2022  12
# 4    28260     도요지로  경서동  722-1         태평샹베르1차  2005   2  84.5496  2022  12
# ..     ...      ...  ...    ...             ...   ...  ..      ...   ...  ..
# 206  28260  청라에메랄드로  청라동  130-4    호반베르디움앤영무예다음  2011  13  59.8600  2022  12
# 207  28260    청라한울로  청라동  149-2  청라제일풍경채2차에듀앤파크  2017   7  84.8460  2022  12
# 208  28260    비즈니스로  청라동   82-1         청라모아미래도  2018  14  71.3679  2022  12
# 209  28260  청라에메랄드로  청라동  130-4    호반베르디움앤영무예다음  2011  17  59.9360  2022  12
# 210  28260    청라커낼로  청라동  156-1      청라센트럴에일린의뜰  2018  10  84.9834  2022  12
#
# ...

# %%
# 특정 년월 자료만 조회하기
df = api.get_data(
    property_type="아파트",
    trade_type="매매",
    sigungu_code="28260",
    year_month="202301",
    )
df
# Out:
#       지역코드          도로명  법정동     지번         아파트  건축년도   층      전용면적     년  월  \
# 0    28260      검암로10번길  검암동  535-2  검암4차신명스카이뷰  2004  13   84.5888  2023  1
# 1    28260          승학로  검암동  629-1     신명스카이뷰1  2003   9   84.9660  2023  1
# 2    28260          승학로  검암동  629-1     신명스카이뷰1  2003  15   59.8810  2023  1
# 3    28260      검암로20번길  검암동  512-1     삼보해피하임3  2003   4   84.8122  2023  1
# 4    28260      검암로20번길  검암동  512-1     삼보해피하임3  2003  17   84.8122  2023  1
# ..     ...          ...  ...    ...         ...   ...  ..       ...   ... ..
# 298  28260  청라에메랄드로76번길  청라동  168-1      호반베르디움  2011  25   84.8520  2023  1
# 299  28260        청라라임로  청라동  185-1       힐데스하임  2011  10   59.9435  2023  1
# 300  28260        크리스탈로  청라동  139-1    청라한화꿈에그린  2012   6  112.9319  2023  1
# 301  28260        청라커낼로  청라동  156-1  청라센트럴에일린의뜰  2018  22   84.9834  2023  1
# 302  28260        비즈니스로  청라동   82-1     청라모아미래도  2018  16   71.3679  2023  1
#
# ...

# %%
# 연습문제: 여러분의 거주 지역 아파트 실거래가를 가져오고 분석해 보세요.
a=df[df['법정동'].str.contains('청라동', na=False)]
a[['아파트','거래금액']]
# Out:
#                아파트   거래금액
# 229          힐데스하임  41500
# 230   청라29블럭호반베르디움  47000
# 231           청라자이  62000
# 232     청라센트럴에일린의뜰  60500
# 233  호반베르디움(116-6)  63000
# ..             ...    ...
# 298         호반베르디움  48500
# 299          힐데스하임  40500
# 300       청라한화꿈에그린  77000
# 301     청라센트럴에일린의뜰  63500
# 302        청라모아미래도  49500
#
# [74 rows x 2 columns]

# %%
# "국토교통부 부동산 실거래 데이터"를 활용하여
# 여러분이 거주하는 동의 관심 아파트 등에 대해
# 거래금액의 추세(선그래프 활용)를 적절히 시각화하시오.
# 기타 의미있는 분석 추가 가능!!!(가점 요인, 대환영!!!)

# 특정 기간 자료 조회하기
df = api.get_data(
    property_type="아파트",
    trade_type="매매",
    sigungu_code="28260",
    start_year_month="202301",
    end_year_month="202302",
    )
df
# Out:
#       지역코드      도로명  법정동      지번               아파트  건축년도   층      전용면적     년  \
# 0    28260  검암로10번길  검암동   535-2        검암4차신명스카이뷰  2004  13   84.5888  2023
# 1    28260      승학로  검암동   629-1           신명스카이뷰1  2003   9   84.9660  2023
# 2    28260      승학로  검암동   629-1           신명스카이뷰1  2003  15   59.8810  2023
# 3    28260  검암로20번길  검암동   512-1           삼보해피하임3  2003   4   84.8122  2023
# 4    28260  검암로20번길  검암동   512-1           삼보해피하임3  2003  17   84.8122  2023
# ..     ...      ...  ...     ...               ...   ...  ..       ...   ...
# 449  28260    비즈니스로  청라동    83-1  청라국제업무단지센텀대광로제비앙  2018  13   82.9117  2023
# 450  28260    비즈니스로  청라동  102-16        청라반도유보라2.0  2012  11  101.9953  2023
# 451  28260      솔빛로  청라동   102-3           청라동양엔파트  2012  12  118.3699  2023
# 452  28260    비즈니스로  청라동    82-1           청라모아미래도  2018   5   71.0928  2023
# 453  28260    비즈니스로  청라동    83-1  청라국제업무단지센텀대광로제비앙  2018  19   82.9117  2023
#
# ...

# %%
a=df[df['법정동'].str.contains('청라동', na=False)]
a[['아파트','거래금액']]
a_sum=a.groupby('아파트', as_index=False)['거래금액'].sum()
a_sum
# Out:
#                    아파트    거래금액
# 0               대우푸르지오   70000
# 1                서해그랑블  281100
# 2             청라 엑슬루타워   57500
# 3         청라29블럭호반베르디움  313000
# 4             청라SKVIEW   64000
# 5          청라골드클래스커낼웨이  117900
# 6   청라국제금융단지한양수자인레이크블루  441000
# 7     청라국제업무단지센텀대광로제비앙  362150
# 8              청라동양엔파트  164000
# 9               청라롯데캐슬  225300
# 10            청라린스트라우스  124500
# 11             청라모아미래도  202500
# 12          청라반도유보라2.0  176700
# 13          청라센트럴에일린의뜰  440000
# 14              청라엘에이치  162700
# 15               청라우미린   48800
# 16           청라웰카운티 2차  147400
# 17            청라웰카운티1차  299000
# 18                청라자이  208000
# 19             청라제일풍경채  135000
# 20      청라제일풍경채2차에듀앤파크  615400
# 21    청라지구중흥S-CLASS1단지  134000
# 22          청라하우스토리커낼뷰   65000
# 23             청라한라비발디   62800
# 24             청라한양수자인   59000
# 25            청라한화꿈에그린  161000
# 26          청라호수공원한신더휴  186000
# 27              호반베르디움   96000
# 28       호반베르디움(116-6)  360700
# ...

# %%
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm

# 한글폰트 다운로드
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
# 마이너스 깨짐 현상 방지
mpl.rcParams['axes.unicode_minus'] = False

plt.rc('font', family='NanumBarunGothic')
# Out:
# NanumBarunGothic

# %%
plt.barh(a_sum['아파트'], a_sum['거래금액'])

plt.show()
