# %% [markdown]
# <a href="https://colab.research.google.com/github/freamwork97/TIS/blob/main/%ED%8C%90%EB%8B%A4%EC%8A%A4%EC%97%B0%EC%8A%B52.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # concat

# %%
import pandas as pd
df1 = pd.DataFrame({'A':[1,2,3],
                    'B':[1,2,3]})
df2 = pd.DataFrame({'A':[4,5],
                    'B':[4,5]})

display(df1)
print('-'*10)
display(df2)
# Out:
#    A  B
# 0  1  1
# 1  2  2
# 2  3  3
# ----------
#    A  B
# 0  4  4
# 1  5  5

# %%
print('ignore_index = True')
display(pd.concat([df1,df2],axis=0, ignore_index=True))
print('-'*10)
print('ignore_index = False')
display(pd.concat([df1,df2],axis=0, ignore_index=False))
# Out:
# ignore_index = True
#    A  B
# 0  1  1
# 1  2  2
# 2  3  3
# 3  4  4
# 4  5  5
# ----------
# ignore_index = False
#    A  B
# 0  1  1
# 1  2  2
# 2  3  3
# 0  4  4
# 1  5  5

# %%
df3 = pd.concat([df1,df2],axis=0, ignore_index=False)
df3.loc[1]
# Out:
#    A  B
# 1  2  2
# 1  5  5

# %%
# 연습
# 두개의 데이터프레임을 위 아래로 연결
# 새로운 통합 인덱스를 부여
import numpy as np

df1 = pd.DataFrame(np.arange(12).reshape(4,3),index=['a','b','c','d'])
df2 = pd.DataFrame(np.arange(12).reshape(4,3),index=['A','B','C','D'])

display(df1)
print('-'*20)
display(df2)

df3=pd.concat([df1,df2],axis=0,ignore_index=True)
print('-'*20)
df3
# Out:
#    0   1   2
# a  0   1   2
# b  3   4   5
# c  6   7   8
# d  9  10  11
# --------------------
#    0   1   2
# A  0   1   2
# B  3   4   5
# C  6   7   8
# D  9  10  11
# --------------------
#    0   1   2
# 0  0   1   2
# 1  3   4   5
# 2  6   7   8
# 3  9  10  11
# 4  0   1   2
# 5  3   4   5
# 6  6   7   8
# 7  9  10  11

# %%
import pandas as pd
df1 = pd.DataFrame({'A':[1,2,3],
                    'B':[1,2,3]})
df2 = pd.DataFrame({'C':[7,8,9]})

display(df1)
print('-'*10)
display(df2)
# Out:
#    A  B
# 0  1  1
# 1  2  2
# 2  3  3
# ----------
#    C
# 0  7
# 1  8
# 2  9

# %%
print('ignore_index = True')
display(pd.concat([df1,df2],axis=1, ignore_index=True))
print('-'*10)
print('ignore_index = False')
display(pd.concat([df1,df2],axis=1, ignore_index=False))
# Out:
# ignore_index = True
#    0  1  2
# 0  1  1  7
# 1  2  2  8
# 2  3  3  9
# ----------
# ignore_index = False
#    A  B  C
# 0  1  1  7
# 1  2  2  8
# 2  3  3  9

# %%
import pandas as pd
df1 = pd.DataFrame({'A':[1,2,3],
                    'B':[1,2,3]})
df2 = pd.DataFrame({'C':[7,8,9]})
df2.index = ['a','b','c']
df2

display(pd.concat([df1,df2],axis=1, ignore_index=False))
display(pd.concat([df1,df2],axis=0, ignore_index=False))
# Out:
#      A    B    C
# 0  1.0  1.0  NaN
# 1  2.0  2.0  NaN
# 2  3.0  3.0  NaN
# a  NaN  NaN  7.0
# b  NaN  NaN  8.0
# c  NaN  NaN  9.0
#      A    B    C
# 0  1.0  1.0  NaN
# 1  2.0  2.0  NaN
# 2  3.0  3.0  NaN
# a  NaN  NaN  7.0
# b  NaN  NaN  8.0
# c  NaN  NaN  9.0

# %% [markdown]
# # merge

# %%
from pandas.core.reshape.merge import merge
import pandas as pd

df1 = pd.DataFrame({'직원':['김철수','박철수','김민수','이민수'],
                    '부서':['회계','데이터분석','데이터분석','인사']})
df2 = pd.DataFrame({'직원':['박철수','이민수','김민수','김철수'],
                    '입사년도':[2004,2008,2012,2014]})

display('df1 :',df1)
display('df2 :',df2)

merged_df = merge(df1,df2)
print('-'*20)
merged_df
# Out:
# 'df1 :'
#     직원     부서
# 0  김철수     회계
# 1  박철수  데이터분석
# 2  김민수  데이터분석
# 3  이민수     인사
# 'df2 :'
#     직원  입사년도
# 0  박철수  2004
# 1  이민수  2008
# 2  김민수  2012
# 3  김철수  2014
# --------------------
#     직원     부서  입사년도
# 0  김철수     회계  2014
# 1  박철수  데이터분석  2004
# 2  김민수  데이터분석  2012
# 3  이민수     인사  2008

# %%
df3 = pd.DataFrame({'직원':['김철수','김민수','김철수','김민수'],
                    '부서':['인사','인사','데이터분석','데이터분석'],
                    '입사년도':[2004,2008,2010,2006]})
df4 = pd.DataFrame({'직원':['박철수','이민수','김민수','김철수'],
                    '입사년도':[2004,2008,2012,2014]})

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TIS/sports.csv')
display(df1)
print('-'*20)
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TIS/subject.csv')
display(df2)
# Out:
#     이름  번호 좋아하는 운동
# 0  김민규   1      축구
# 1  임재광   2      농구
# 2   최선   3      배구
# 3  정승용   4      족구
# 4  강재훈   5      배구
# 5  장윤제   6      축구
# 6  고연서   7      피구
# 7  유원종   8   아이스하키
# 8  채관수   9      하키
# 9  김중교  10      축구
# --------------------
#     성명  번호 좋아하는 과목
# 0  김민규   1      영어
# 1  임재광   2      수학
# 2   최선   3      과학
# 3  정승용   4      국어
# 4  강재훈   5      역사
# 5  장윤제   6      지리
# 6  고연서   7      사회
# 7  유원종   8      음악
# 8  채관수   9      미술
# 9  김중교  10      역사

# %%
df3 = merge(df1,df2,left_on=['이름','번호'],right_on=['성명','번호'])
display(df3)
# Out:
#     이름  번호 좋아하는 운동   성명 좋아하는 과목
# 0  김민규   1      축구  김민규      영어
# 1  임재광   2      농구  임재광      수학
# 2   최선   3      배구   최선      과학
# 3  정승용   4      족구  정승용      국어
# 4  강재훈   5      배구  강재훈      역사
# 5  장윤제   6      축구  장윤제      지리
# 6  고연서   7      피구  고연서      사회
# 7  유원종   8   아이스하키  유원종      음악
# 8  채관수   9      하키  채관수      미술
# 9  김중교  10      축구  김중교      역사

# %%
df3.drop('성명',axis=1,inplace=True)
df3
# Out:
#     이름  번호 좋아하는 운동 좋아하는 과목
# 0  김민규   1      축구      영어
# 1  임재광   2      농구      수학
# 2   최선   3      배구      과학
# 3  정승용   4      족구      국어
# 4  강재훈   5      배구      역사
# 5  장윤제   6      축구      지리
# 6  고연서   7      피구      사회
# 7  유원종   8   아이스하키      음악
# 8  채관수   9      하키      미술
# 9  김중교  10      축구      역사

# %%
df2.columns = ['이름','번호','좋아하는 과목']

df4 = merge(df1,df2)
df4
# Out:
#     이름  번호 좋아하는 운동 좋아하는 과목
# 0  김민규   1      축구      영어
# 1  임재광   2      농구      수학
# 2   최선   3      배구      과학
# 3  정승용   4      족구      국어
# 4  강재훈   5      배구      역사
# 5  장윤제   6      축구      지리
# 6  고연서   7      피구      사회
# 7  유원종   8   아이스하키      음악
# 8  채관수   9      하키      미술
# 9  김중교  10      축구      역사

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TIS/sports.csv')
display(df1)
print('-'*20)
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TIS/subject.csv')
display(df2)
# Out:
#     이름  번호 좋아하는 운동
# 0  김민규   1      축구
# 1  임재광   2      농구
# 2   최선   3      배구
# 3  정승용   4      족구
# 4  강재훈   5      배구
# 5  장윤제   6      축구
# 6  고연서   7      피구
# 7  유원종   8   아이스하키
# 8  채관수   9      하키
# 9  김중교  10      축구
# --------------------
#     성명  번호 좋아하는 과목
# 0  김민규   1      영어
# 1  임재광   2      수학
# 2   최선   3      과학
# 3  정승용   4      국어
# 4  강재훈   5      역사
# 5  장윤제   6      지리
# 6  고연서   7      사회
# 7  유원종   8      음악
# 8  채관수   9      미술
# 9  김중교  10      역사

# %%
df2.rename({'성명':'성함'},axis = 1,inplace=True) # 성명->성함
df2
# Out:
#     성함  번호 좋아하는 과목
# 0  김민규   1      영어
# 1  임재광   2      수학
# 2   최선   3      과학
# 3  정승용   4      국어
# 4  강재훈   5      역사
# 5  장윤제   6      지리
# 6  고연서   7      사회
# 7  유원종   8      음악
# 8  채관수   9      미술
# 9  김중교  10      역사

# %%
df2.rename({'성함':'이름'}, axis= 1, inplace=True) # 성함 -> 이름
df3 = merge(df1,df2)
df3
# Out:
#     이름  번호 좋아하는 운동 좋아하는 과목
# 0  김민규   1      축구      영어
# 1  임재광   2      농구      수학
# 2   최선   3      배구      과학
# 3  정승용   4      족구      국어
# 4  강재훈   5      배구      역사
# 5  장윤제   6      축구      지리
# 6  고연서   7      피구      사회
# 7  유원종   8   아이스하키      음악
# 8  채관수   9      하키      미술
# 9  김중교  10      축구      역사

# %%
import pandas as pd

df1 = pd.DataFrame({'직원':['김철수','박철수','김민수','이민수'],
                    '부서':['회계','데이터분석','데이터분석','인사']})
df2 = pd.DataFrame({'직원':['박철수','이민수','김민수','김철수'],
                    '입사년도':[2004,2008,2012,2014]})

display('df1 :',df1)
display('df2 :',df2)
# Out:
# 'df1 :'
#     직원     부서
# 0  김철수     회계
# 1  박철수  데이터분석
# 2  김민수  데이터분석
# 3  이민수     인사
# 'df2 :'
#     직원  입사년도
# 0  박철수  2004
# 1  이민수  2008
# 2  김민수  2012
# 3  김철수  2014

# %%
df1 = pd.DataFrame({'key':[1,2,3],'x':[1,2,3]})
df2 = pd.DataFrame({'key':[2,3,4],'y':[2,3,4]})
display(df1)
print('-'*10)
display(df2)
# Out:
#    key  x
# 0    1  1
# 1    2  2
# 2    3  3
# ----------
#    key  y
# 0    2  2
# 1    3  3
# 2    4  4

# %%
display(pd.merge(df1,df2, on='key',how='inner'))
# Out:
#    key  x  y
# 0    2  2  2
# 1    3  3  3

# %%
display(pd.merge(df1,df2, on='key',how='left'))
# Out:
#    key  x    y
# 0    1  1  NaN
# 1    2  2  2.0
# 2    3  3  3.0

# %%
display(pd.merge(df1,df2, on='key',how='right'))
# Out:
#    key    x  y
# 0    2  2.0  2
# 1    3  3.0  3
# 2    4  NaN  4

# %%
display(pd.merge(df1,df2, on='key',how='outer'))
# Out:
#    key    x    y
# 0    1  1.0  NaN
# 1    2  2.0  2.0
# 2    3  3.0  3.0
# 3    4  NaN  4.0

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TIS/sports.csv')
display(df1)
print('-'*20)
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TIS/subject.csv')
display(df2)
# Out:
#     이름  번호 좋아하는 운동
# 0  김민규   1      축구
# 1  임재광   2      농구
# 2   최선   3      배구
# 3  정승용   4      족구
# 4  강재훈   5      배구
# 5  장윤제   6      축구
# 6  고연서   7      피구
# 7  유원종   8   아이스하키
# 8  채관수   9      하키
# 9  김중교  10      축구
# --------------------
#     성명  번호 좋아하는 과목
# 0  김민규   1      영어
# 1  임재광   2      수학
# 2   최선   3      과학
# 3  정승용   4      국어
# 4  강재훈   5      역사
# 5  장윤제   6      지리
# 6  고연서   7      사회
# 7  유원종   8      음악
# 8  채관수   9      미술
# 9  김중교  10      역사

# %%
# 각 데이터프레임에서 서로 다른 이름을 가진행 하나씩 제거(drop 메서드 활용)
# 그 다음 데이터프레임을 병합
# how의 4가지 방법 다 써보기

df1.drop(9,axis=0, inplace=True)
df2.drop(8,axis=0, inplace=True)
display(df1)
display(df2)
# Out:
#     이름  번호 좋아하는 운동
# 0  김민규   1      축구
# 1  임재광   2      농구
# 2   최선   3      배구
# 3  정승용   4      족구
# 4  강재훈   5      배구
# 5  장윤제   6      축구
# 6  고연서   7      피구
# 7  유원종   8   아이스하키
# 8  채관수   9      하키
#     성명  번호 좋아하는 과목
# 0  김민규   1      영어
# 1  임재광   2      수학
# 2   최선   3      과학
# 3  정승용   4      국어
# 4  강재훈   5      역사
# 5  장윤제   6      지리
# 6  고연서   7      사회
# 7  유원종   8      음악
# 9  김중교  10      역사

# %%
display(pd.merge(df1,df2, on='번호',how='inner'))
# Out:
#     이름  번호 좋아하는 운동   성명 좋아하는 과목
# 0  김민규   1      축구  김민규      영어
# 1  임재광   2      농구  임재광      수학
# 2   최선   3      배구   최선      과학
# 3  정승용   4      족구  정승용      국어
# 4  강재훈   5      배구  강재훈      역사
# 5  장윤제   6      축구  장윤제      지리
# 6  고연서   7      피구  고연서      사회
# 7  유원종   8   아이스하키  유원종      음악

# %%
display(pd.merge(df1,df2, on='번호',how='left'))
# Out:
#     이름  번호 좋아하는 운동   성명 좋아하는 과목
# 0  김민규   1      축구  김민규      영어
# 1  임재광   2      농구  임재광      수학
# 2   최선   3      배구   최선      과학
# 3  정승용   4      족구  정승용      국어
# 4  강재훈   5      배구  강재훈      역사
# 5  장윤제   6      축구  장윤제      지리
# 6  고연서   7      피구  고연서      사회
# 7  유원종   8   아이스하키  유원종      음악
# 8  채관수   9      하키  NaN     NaN

# %%
display(pd.merge(df1,df2, on='번호',how='right'))
# Out:
#     이름  번호 좋아하는 운동   성명 좋아하는 과목
# 0  김민규   1      축구  김민규      영어
# 1  임재광   2      농구  임재광      수학
# 2   최선   3      배구   최선      과학
# 3  정승용   4      족구  정승용      국어
# 4  강재훈   5      배구  강재훈      역사
# 5  장윤제   6      축구  장윤제      지리
# 6  고연서   7      피구  고연서      사회
# 7  유원종   8   아이스하키  유원종      음악
# 8  NaN  10     NaN  김중교      역사

# %%
display(pd.merge(df1,df2, on='번호',how='outer'))
# Out:
#     이름  번호 좋아하는 운동   성명 좋아하는 과목
# 0  김민규   1      축구  김민규      영어
# 1  임재광   2      농구  임재광      수학
# 2   최선   3      배구   최선      과학
# 3  정승용   4      족구  정승용      국어
# 4  강재훈   5      배구  강재훈      역사
# 5  장윤제   6      축구  장윤제      지리
# 6  고연서   7      피구  고연서      사회
# 7  유원종   8   아이스하키  유원종      음악
# 8  채관수   9      하키  NaN     NaN
# 9  NaN  10     NaN  김중교      역사

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TIS/sports.csv')
display(df1)
print('-'*20)
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TIS/subject.csv')
display(df2)
# Out:
#     이름  번호 좋아하는 운동
# 0  김민규   1      축구
# 1  임재광   2      농구
# 2   최선   3      배구
# 3  정승용   4      족구
# 4  강재훈   5      배구
# 5  장윤제   6      축구
# 6  고연서   7      피구
# 7  유원종   8   아이스하키
# 8  채관수   9      하키
# 9  김중교  10      축구
# --------------------
#     성명  번호 좋아하는 과목
# 0  김민규   1      영어
# 1  임재광   2      수학
# 2   최선   3      과학
# 3  정승용   4      국어
# 4  강재훈   5      역사
# 5  장윤제   6      지리
# 6  고연서   7      사회
# 7  유원종   8      음악
# 8  채관수   9      미술
# 9  김중교  10      역사

# %%
df2.rename({'성명':'이름'},axis=1,inplace=True)
df2
# Out:
#     이름  번호 좋아하는 과목
# 0  김민규   1      영어
# 1  임재광   2      수학
# 2   최선   3      과학
# 3  정승용   4      국어
# 4  강재훈   5      역사
# 5  장윤제   6      지리
# 6  고연서   7      사회
# 7  유원종   8      음악
# 8  채관수   9      미술
# 9  김중교  10      역사

# %%
# 각 데이터프레임에서 서로 다른 이름을 가진행 하나씩 제거(drop 메서드 활용)
# 그 다음 데이터프레임을 병합
# how의 4가지 방법 다 써보기

df1.drop(9,axis=0, inplace=True)
df2.drop(8,axis=0, inplace=True)
display(df1)
display(df2)
# Out:
#     이름  번호 좋아하는 운동
# 0  김민규   1      축구
# 1  임재광   2      농구
# 2   최선   3      배구
# 3  정승용   4      족구
# 4  강재훈   5      배구
# 5  장윤제   6      축구
# 6  고연서   7      피구
# 7  유원종   8   아이스하키
# 8  채관수   9      하키
#     이름  번호 좋아하는 과목
# 0  김민규   1      영어
# 1  임재광   2      수학
# 2   최선   3      과학
# 3  정승용   4      국어
# 4  강재훈   5      역사
# 5  장윤제   6      지리
# 6  고연서   7      사회
# 7  유원종   8      음악
# 9  김중교  10      역사

# %%
display(pd.merge(df1,df2, on=['이름','번호'],how='inner'))
# Out:
#     이름  번호 좋아하는 운동 좋아하는 과목
# 0  김민규   1      축구      영어
# 1  임재광   2      농구      수학
# 2   최선   3      배구      과학
# 3  정승용   4      족구      국어
# 4  강재훈   5      배구      역사
# 5  장윤제   6      축구      지리
# 6  고연서   7      피구      사회
# 7  유원종   8   아이스하키      음악

# %%
display(pd.merge(df1,df2, on=['이름','번호'],how='left'))
# Out:
#     이름  번호 좋아하는 운동 좋아하는 과목
# 0  김민규   1      축구      영어
# 1  임재광   2      농구      수학
# 2   최선   3      배구      과학
# 3  정승용   4      족구      국어
# 4  강재훈   5      배구      역사
# 5  장윤제   6      축구      지리
# 6  고연서   7      피구      사회
# 7  유원종   8   아이스하키      음악
# 8  채관수   9      하키     NaN

# %%
display(pd.merge(df1,df2, on=['이름','번호'],how='right'))
# Out:
#     이름  번호 좋아하는 운동 좋아하는 과목
# 0  김민규   1      축구      영어
# 1  임재광   2      농구      수학
# 2   최선   3      배구      과학
# 3  정승용   4      족구      국어
# 4  강재훈   5      배구      역사
# 5  장윤제   6      축구      지리
# 6  고연서   7      피구      사회
# 7  유원종   8   아이스하키      음악
# 8  김중교  10     NaN      역사

# %%
display(pd.merge(df1,df2, on=['이름','번호'],how='outer'))
# Out:
#     이름  번호 좋아하는 운동 좋아하는 과목
# 0  김민규   1      축구      영어
# 1  임재광   2      농구      수학
# 2   최선   3      배구      과학
# 3  정승용   4      족구      국어
# 4  강재훈   5      배구      역사
# 5  장윤제   6      축구      지리
# 6  고연서   7      피구      사회
# 7  유원종   8   아이스하키      음악
# 8  채관수   9      하키     NaN
# 9  김중교  10     NaN      역사

# %%
path='/content/drive/MyDrive/Colab Notebooks/TIS/재무제표샘플데이터.csv'

df=pd.read_csv(path,encoding='euc-kr')

# %%
df.head()
# Out:
#       기업    연도          자산총계          부채총계          자본총계           매출액  \
# 0  대원미디어  2016  9.776068e+10  2.341949e+10  7.434119e+10  9.499312e+10
# 1  대원미디어  2017  1.043490e+11  2.339887e+10  8.095035e+10  1.207350e+11
# 2  대원미디어  2018  1.255730e+11  2.402737e+10  1.015450e+11  1.633750e+11
# 3  대원미디어  2019  1.361390e+11  3.494140e+10  1.011980e+11  1.915460e+11
# 4  대원미디어  2020  1.446900e+11  3.545975e+10  1.092300e+11  2.662270e+11
#
#            영업이익         당기순이익       부채비율
# 0  2.379823e+09  4.804263e+08  76.044057
# 1  6.987071e+09  7.797097e+09  77.576381
# 2  6.412992e+09  4.153603e+09  80.865781
# 3  3.664066e+09  3.181392e+09  74.334031
# 4  7.227984e+09  6.501209e+09  75.492644

# %%
df.tail()
# Out:
#      기업    연도          자산총계          부채총계          자본총계           매출액  \
# 35  코오롱  2016  3.332550e+12  2.502330e+12  8.302250e+11  3.936860e+12
# 36  코오롱  2017  3.688370e+12  2.785430e+12  9.029420e+11  4.405820e+12
# 37  코오롱  2018  3.473910e+12  2.644700e+12  8.292060e+11  4.324490e+12
# 38  코오롱  2019  3.618570e+12  2.896670e+12  7.219040e+11  4.284390e+12
# 39  코오롱  2020  3.708130e+12  2.849100e+12  8.590350e+11  4.890150e+12
#
#             영업이익         당기순이익       부채비율
# 35  1.332050e+11  2.745606e+10  24.912568
# 36  1.089940e+11  9.852028e+10  24.480781
# 37  1.050160e+11 -4.522544e+09  23.869540
# 38  1.343990e+11 -2.222093e+10  19.949944
# 39  2.714480e+11  1.666080e+11  23.166223

# %%
df
# Out:
#          기업    연도          자산총계          부채총계          자본총계           매출액  \
# 0     대원미디어  2016  9.776068e+10  2.341949e+10  7.434119e+10  9.499312e+10
# 1     대원미디어  2017  1.043490e+11  2.339887e+10  8.095035e+10  1.207350e+11
# 2     대원미디어  2018  1.255730e+11  2.402737e+10  1.015450e+11  1.633750e+11
# 3     대원미디어  2019  1.361390e+11  3.494140e+10  1.011980e+11  1.915460e+11
# 4     대원미디어  2020  1.446900e+11  3.545975e+10  1.092300e+11  2.662270e+11
# 5   서울바이오시스  2016           NaN           NaN           NaN           NaN
# 6   서울바이오시스  2017           NaN           NaN           NaN           NaN
# 7   서울바이오시스  2018  4.140130e+11  2.530460e+11  1.609670e+11  3.864120e+11
# 8   서울바이오시스  2019  5.790810e+11  3.915870e+11  1.874940e+11  3.506400e+11
# 9   서울바이오시스  2020  5.828830e+11  3.635450e+11  2.193370e+11  4.312820e+11
# 10  솔브레인홀딩스  2016  8.293910e+11  2.684180e+11  5.609730e+11  7.225210e+11
# 11  솔브레인홀딩스  2017  8.959500e+11  2.460910e+11  6.498590e+11  7.755980e+11
# ...

# %%
df.describe()
# Out:
#                연도          자산총계          부채총계          자본총계           매출액  \
# count    40.00000  3.600000e+01  3.600000e+01  3.600000e+01  3.300000e+01
# mean   2018.00000  7.826858e+11  4.942808e+11  2.884053e+11  8.516524e+11
# std       1.43223  1.186074e+12  9.228289e+11  3.339497e+11  1.529365e+12
# min    2016.00000  2.949228e+10  6.320311e+09  1.054736e+10  1.249716e+10
# 25%    2017.00000  5.521337e+10  2.387540e+10  2.931327e+10  3.285967e+10
# 50%    2018.00000  2.653375e+11  1.312652e+11  1.350985e+11  1.915460e+11
# 75%    2019.00000  8.460308e+11  2.958292e+11  5.831945e+11  4.924430e+11
# max    2020.00000  3.708130e+12  2.896670e+12  1.036090e+12  4.890150e+12
#
#                영업이익         당기순이익       부채비율
# count  3.600000e+01  3.600000e+01  36.000000
# mean   3.046763e+10  5.503761e+10  53.050860
# std    5.955260e+10  2.421778e+11  21.717672
# min   -1.162015e+10 -4.402732e+10  18.883905
# 25%    2.295892e+09 -5.813147e+09  36.316790
# ...

# %%
df.shape
# Out:
# (40, 9)

# %%
print(df.shape)
# Out:
# (40, 9)

# %%
print(df.index)
print('-'*20)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=40, step=1)
# --------------------
# Index(['기업', '연도', '자산총계', '부채총계', '자본총계', '매출액', '영업이익', '당기순이익', '부채비율'], dtype='object')

# %%
print(type(df.index))
print(type(df.columns))
# Out:
# <class 'pandas.core.indexes.range.RangeIndex'>
# <class 'pandas.core.indexes.base.Index'>

# %%
df['부채비율>50'] = df['부채비율'] > 50
df['부채비율>50']
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28     True
# 29     True
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# Name: 부채비율>50, dtype: bool

# %%
df
# Out:
#          기업    연도          자산총계          부채총계          자본총계           매출액  \
# 0     대원미디어  2016  9.776068e+10  2.341949e+10  7.434119e+10  9.499312e+10
# 1     대원미디어  2017  1.043490e+11  2.339887e+10  8.095035e+10  1.207350e+11
# 2     대원미디어  2018  1.255730e+11  2.402737e+10  1.015450e+11  1.633750e+11
# 3     대원미디어  2019  1.361390e+11  3.494140e+10  1.011980e+11  1.915460e+11
# 4     대원미디어  2020  1.446900e+11  3.545975e+10  1.092300e+11  2.662270e+11
# 5   서울바이오시스  2016           NaN           NaN           NaN           NaN
# 6   서울바이오시스  2017           NaN           NaN           NaN           NaN
# 7   서울바이오시스  2018  4.140130e+11  2.530460e+11  1.609670e+11  3.864120e+11
# 8   서울바이오시스  2019  5.790810e+11  3.915870e+11  1.874940e+11  3.506400e+11
# 9   서울바이오시스  2020  5.828830e+11  3.635450e+11  2.193370e+11  4.312820e+11
# 10  솔브레인홀딩스  2016  8.293910e+11  2.684180e+11  5.609730e+11  7.225210e+11
# 11  솔브레인홀딩스  2017  8.959500e+11  2.460910e+11  6.498590e+11  7.755980e+11
# ...

# %%
display(df['부채비율>50'].value_counts())
# Out:
# False    22
# True     18
# Name: 부채비율>50, dtype: int64

# %%
# df에서 기업의 수는?
display(df['기업'].value_counts())
# Out:
# 대원미디어      5
# 서울바이오시스    5
# 솔브레인홀딩스    5
# 쎄미시스코      5
# 엔에프씨       5
# 유테크        5
# 인터지스       5
# 코오롱        5
# Name: 기업, dtype: int64

# %%
# 비율
display(df['기업'].value_counts(normalize=True))
# Out:
# 대원미디어      0.125
# 서울바이오시스    0.125
# 솔브레인홀딩스    0.125
# 쎄미시스코      0.125
# 엔에프씨       0.125
# 유테크        0.125
# 인터지스       0.125
# 코오롱        0.125
# Name: 기업, dtype: float64

# %%
result = df['부채비율>50'].value_counts()
print(result.index[0], result.iloc[0])
# Out:
# False 22

# %%
df['부채비율>50'].value_counts(normalize=True).plot(kind = 'bar',color ='purple')

# %%
df['부채비율>50'].value_counts(normalize=True).plot(kind = 'pie')

# %%
display(df.describe())
# Out:
#                연도          자산총계          부채총계          자본총계           매출액  \
# count    40.00000  3.600000e+01  3.600000e+01  3.600000e+01  3.300000e+01
# mean   2018.00000  7.826858e+11  4.942808e+11  2.884053e+11  8.516524e+11
# std       1.43223  1.186074e+12  9.228289e+11  3.339497e+11  1.529365e+12
# min    2016.00000  2.949228e+10  6.320311e+09  1.054736e+10  1.249716e+10
# 25%    2017.00000  5.521337e+10  2.387540e+10  2.931327e+10  3.285967e+10
# 50%    2018.00000  2.653375e+11  1.312652e+11  1.350985e+11  1.915460e+11
# 75%    2019.00000  8.460308e+11  2.958292e+11  5.831945e+11  4.924430e+11
# max    2020.00000  3.708130e+12  2.896670e+12  1.036090e+12  4.890150e+12
#
#                영업이익         당기순이익       부채비율
# count  3.600000e+01  3.600000e+01  36.000000
# mean   3.046763e+10  5.503761e+10  53.050860
# std    5.955260e+10  2.421778e+11  21.717672
# min   -1.162015e+10 -4.402732e+10  18.883905
# 25%    2.295892e+09 -5.813147e+09  36.316790
# ...

# %%
df.count()
# Out:
# 기업         40
# 연도         40
# 자산총계       36
# 부채총계       36
# 자본총계       36
# 매출액        33
# 영업이익       36
# 당기순이익      36
# 부채비율       36
# 부채비율>50    40
# dtype: int64

# %%
df.std()
# Out:
# <ipython-input-295-ce97bb7eaef8>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# 연도         1.432230e+00
# 자산총계       1.186074e+12
# 부채총계       9.228289e+11
# 자본총계       3.339497e+11
# 매출액        1.529365e+12
# 영업이익       5.955260e+10
# 당기순이익      2.421778e+11
# 부채비율       2.171767e+01
# 부채비율>50    5.038315e-01
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-296-c61f0c8f89b5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# 연도         2.018000e+03
# 자산총계       7.826858e+11
# 부채총계       4.942808e+11
# 자본총계       2.884053e+11
# 매출액        8.516524e+11
# 영업이익       3.046763e+10
# 당기순이익      5.503761e+10
# 부채비율       5.305086e+01
# 부채비율>50    4.500000e-01
# dtype: float64

# %%
df.min()
# Out:
# 기업                 대원미디어
# 연도                  2016
# 자산총계       29492284615.0
# 부채총계        6320311155.0
# 자본총계       10547363657.0
# 매출액        12497160311.0
# 영업이익      -11620146155.0
# 당기순이익     -44027324529.0
# 부채비율           18.883905
# 부채비율>50            False
# dtype: object

# %%
df['매출액'].quantile(0.7)
# Out:
# 470505800000.0

# %%
df[['매출액','영업이익','당기순이익']].quantile(0.7)
# Out:
# 매출액      4.705058e+11
# 영업이익     1.466198e+10
# 당기순이익    6.972623e+09
# Name: 0.7, dtype: float64

# %%
# 매출액, 영업이익에 대해
# 최대값 최소값인 기업 및 해당연도
display(df[['기업','매출액','영업이익','연도']].max())
display(df[['기업','매출액','영업이익','연도']].min())
# Out:
# 기업                  코오롱
# 매출액     4890150000000.0
# 영업이익     271448000000.0
# 연도                 2020
# dtype: object
# 기업              대원미디어
# 매출액     12497160311.0
# 영업이익   -11620146155.0
# 연도               2016
# dtype: object

# %%
df[df['매출액']==df['매출액'].max()]
# Out:
#      기업    연도          자산총계          부채총계          자본총계           매출액  \
# 39  코오롱  2020  3.708130e+12  2.849100e+12  8.590350e+11  4.890150e+12
#
#             영업이익         당기순이익       부채비율  부채비율>50
# 39  2.714480e+11  1.666080e+11  23.166223    False

# %%
df.groupby('기업')['영업이익'].max()
# Out:
# 기업
# 대원미디어      7.227984e+09
# 서울바이오시스    2.738493e+10
# 솔브레인홀딩스    1.056940e+11
# 쎄미시스코      3.346492e+09
# 엔에프씨       6.821097e+09
# 유테크        2.044100e+09
# 인터지스       1.490524e+10
# 코오롱        2.714480e+11
# Name: 영업이익, dtype: float64

# %%
df.groupby(['연도','부채비율>50'])['영업이익'].max()
# Out:
# 연도    부채비율>50
# 2016  False      1.332050e+11
#       True       1.051390e+11
# 2017  False      1.089940e+11
#       True       1.056940e+11
# 2018  False      1.050160e+11
#       True       6.412992e+09
# 2019  False      1.343990e+11
#       True       1.441873e+10
# 2020  False      2.714480e+11
#       True       1.657536e+10
# Name: 영업이익, dtype: float64

# %%
df.groupby(['연도','부채비율>50'],as_index=False)['영업이익'].max()
# Out:
#      연도  부채비율>50          영업이익
# 0  2016    False  1.332050e+11
# 1  2016     True  1.051390e+11
# 2  2017    False  1.089940e+11
# 3  2017     True  1.056940e+11
# 4  2018    False  1.050160e+11
# 5  2018     True  6.412992e+09
# 6  2019    False  1.343990e+11
# 7  2019     True  1.441873e+10
# 8  2020    False  2.714480e+11
# 9  2020     True  1.657536e+10

# %%
# 연습
# 기업별, 5개년도의 매출액의 평균
df.groupby(['기업','연도'],as_index=False)['매출액'].mean()
# Out:
#          기업    연도           매출액
# 0     대원미디어  2016  9.499312e+10
# 1     대원미디어  2017  1.207350e+11
# 2     대원미디어  2018  1.633750e+11
# 3     대원미디어  2019  1.915460e+11
# 4     대원미디어  2020  2.662270e+11
# 5   서울바이오시스  2016           NaN
# 6   서울바이오시스  2017           NaN
# 7   서울바이오시스  2018  3.864120e+11
# 8   서울바이오시스  2019  3.506400e+11
# 9   서울바이오시스  2020  4.312820e+11
# 10  솔브레인홀딩스  2016  7.225210e+11
# 11  솔브레인홀딩스  2017  7.755980e+11
# 12  솔브레인홀딩스  2018           NaN
# 13  솔브레인홀딩스  2019           NaN
# 14  솔브레인홀딩스  2020           NaN
# 15    쎄미시스코  2016  1.249716e+10
# 16    쎄미시스코  2017  2.502729e+10
# 17    쎄미시스코  2018  2.193183e+10
# 18    쎄미시스코  2019  1.708326e+10
# 19    쎄미시스코  2020  1.364068e+10
# 20     엔에프씨  2016           NaN
# 21     엔에프씨  2017           NaN
# 22     엔에프씨  2018  2.404593e+10
# 23     엔에프씨  2019  3.285967e+10
# 24     엔에프씨  2020  3.332451e+10
# 25      유테크  2016  2.835045e+10
# 26      유테크  2017  3.198969e+10
# 27      유테크  2018  5.257768e+10
# ...

# %%
# 연습
# 기업별, 5개년도의 매출액의 최소
df.groupby(['기업','연도'],as_index=False)['매출액'].min()
# Out:
#          기업    연도           매출액
# 0     대원미디어  2016  9.499312e+10
# 1     대원미디어  2017  1.207350e+11
# 2     대원미디어  2018  1.633750e+11
# 3     대원미디어  2019  1.915460e+11
# 4     대원미디어  2020  2.662270e+11
# 5   서울바이오시스  2016           NaN
# 6   서울바이오시스  2017           NaN
# 7   서울바이오시스  2018  3.864120e+11
# 8   서울바이오시스  2019  3.506400e+11
# 9   서울바이오시스  2020  4.312820e+11
# 10  솔브레인홀딩스  2016  7.225210e+11
# 11  솔브레인홀딩스  2017  7.755980e+11
# 12  솔브레인홀딩스  2018           NaN
# 13  솔브레인홀딩스  2019           NaN
# 14  솔브레인홀딩스  2020           NaN
# 15    쎄미시스코  2016  1.249716e+10
# 16    쎄미시스코  2017  2.502729e+10
# 17    쎄미시스코  2018  2.193183e+10
# 18    쎄미시스코  2019  1.708326e+10
# 19    쎄미시스코  2020  1.364068e+10
# 20     엔에프씨  2016           NaN
# 21     엔에프씨  2017           NaN
# 22     엔에프씨  2018  2.404593e+10
# 23     엔에프씨  2019  3.285967e+10
# 24     엔에프씨  2020  3.332451e+10
# 25      유테크  2016  2.835045e+10
# 26      유테크  2017  3.198969e+10
# 27      유테크  2018  5.257768e+10
# ...

# %%
# 연습
# 기업별, 5개년도의 매출액의 최대
df.groupby(['기업','연도'],as_index=False)['매출액'].max()
# Out:
#          기업    연도           매출액
# 0     대원미디어  2016  9.499312e+10
# 1     대원미디어  2017  1.207350e+11
# 2     대원미디어  2018  1.633750e+11
# 3     대원미디어  2019  1.915460e+11
# 4     대원미디어  2020  2.662270e+11
# 5   서울바이오시스  2016           NaN
# 6   서울바이오시스  2017           NaN
# 7   서울바이오시스  2018  3.864120e+11
# 8   서울바이오시스  2019  3.506400e+11
# 9   서울바이오시스  2020  4.312820e+11
# 10  솔브레인홀딩스  2016  7.225210e+11
# 11  솔브레인홀딩스  2017  7.755980e+11
# 12  솔브레인홀딩스  2018           NaN
# 13  솔브레인홀딩스  2019           NaN
# 14  솔브레인홀딩스  2020           NaN
# 15    쎄미시스코  2016  1.249716e+10
# 16    쎄미시스코  2017  2.502729e+10
# 17    쎄미시스코  2018  2.193183e+10
# 18    쎄미시스코  2019  1.708326e+10
# 19    쎄미시스코  2020  1.364068e+10
# 20     엔에프씨  2016           NaN
# 21     엔에프씨  2017           NaN
# 22     엔에프씨  2018  2.404593e+10
# 23     엔에프씨  2019  3.285967e+10
# 24     엔에프씨  2020  3.332451e+10
# 25      유테크  2016  2.835045e+10
# 26      유테크  2017  3.198969e+10
# 27      유테크  2018  5.257768e+10
# ...

# %%
display(df.groupby('기업')['매출액'].max(),'-'*20)
display(df.groupby('기업')['매출액'].min(),'-'*20)
display(df.groupby('기업')['매출액'].mean(),'-'*20)
# Out:
# 기업
# 대원미디어      2.662270e+11
# 서울바이오시스    4.312820e+11
# 솔브레인홀딩스    7.755980e+11
# 쎄미시스코      2.502729e+10
# 엔에프씨       3.332451e+10
# 유테크        5.257768e+10
# 인터지스       5.019650e+11
# 코오롱        4.890150e+12
# Name: 매출액, dtype: float64
# '--------------------'
# 기업
# 대원미디어      9.499312e+10
# 서울바이오시스    3.506400e+11
# 솔브레인홀딩스    7.225210e+11
# 쎄미시스코      1.249716e+10
# 엔에프씨       2.404593e+10
# 유테크        2.835045e+10
# 인터지스       4.583170e+11
# 코오롱        3.936860e+12
# Name: 매출액, dtype: float64
# '--------------------'
# 기업
# 대원미디어      1.673752e+11
# 서울바이오시스    3.894447e+11
# 솔브레인홀딩스    7.490595e+11
# 쎄미시스코      1.803604e+10
# 엔에프씨       3.007670e+10
# 유테크        3.655787e+10
# 인터지스       4.792582e+11
# 코오롱        4.368342e+12
# Name: 매출액, dtype: float64
# '--------------------'

# %%
df.groupby(['기업','부채비율>50'],as_index=False)['부채비율'].mean()
# Out:
#         기업  부채비율>50       부채비율
# 0    대원미디어     True  76.862579
# 1  서울바이오시스    False  36.295803
# 2  솔브레인홀딩스     True  72.609885
# 3    쎄미시스코     True  72.631166
# 4     엔에프씨    False  34.578321
# 5     엔에프씨     True  65.397306
# 6      유테크    False  26.588315
# 7      유테크     True  64.829664
# 8     인터지스    False  46.013621
# 9      코오롱    False  23.275811

# %%
a=df.groupby(['기업','부채비율>50'],as_index=False)['부채비율'].mean()
a.rename({'부채비율':'부채비율의 평균'},axis = 1,inplace=True) 
a
# Out:
#         기업  부채비율>50   부채비율의 평균
# 0    대원미디어     True  76.862579
# 1  서울바이오시스    False  36.295803
# 2  솔브레인홀딩스     True  72.609885
# 3    쎄미시스코     True  72.631166
# 4     엔에프씨    False  34.578321
# 5     엔에프씨     True  65.397306
# 6      유테크    False  26.588315
# 7      유테크     True  64.829664
# 8     인터지스    False  46.013621
# 9      코오롱    False  23.275811

# %%
import numpy as np
df.groupby(['기업'],as_index=False)[['영업이익','매출액']].agg([max,min,np.mean])
# Out:
#                  영업이익                                       매출액                \
#                   max           min          mean           max           min
# 기업
# 대원미디어    7.227984e+09  2.379823e+09  5.334387e+09  2.662270e+11  9.499312e+10
# 서울바이오시스  2.738493e+10  1.025616e+10  1.811337e+10  4.312820e+11  3.506400e+11
# 솔브레인홀딩스  1.056940e+11  4.624502e+09  4.929032e+10  7.755980e+11  7.225210e+11
# 쎄미시스코    3.346492e+09 -7.782689e+09 -2.289212e+09  2.502729e+10  1.249716e+10
# 엔에프씨     6.821097e+09  3.838921e+09  5.071872e+09  3.332451e+10  2.404593e+10
# 유테크      2.044100e+09 -1.162015e+10 -7.330405e+09  5.257768e+10  2.835045e+10
# 인터지스     1.490524e+10  6.479330e+09  9.838269e+09  5.019650e+11  4.583170e+11
# 코오롱      2.714480e+11  1.050160e+11  1.506124e+11  4.890150e+12  3.936860e+12
#
#
#                  mean
# 기업
# 대원미디어    1.673752e+11
# 서울바이오시스  3.894447e+11
# 솔브레인홀딩스  7.490595e+11
# 쎄미시스코    1.803604e+10
# 엔에프씨     3.007670e+10
# 유테크      3.655787e+10
# ...

# %%
import numpy as np
df.groupby(['기업'],as_index=False)[['영업이익','매출액']].agg({'영업이익':[max,min],'매출액':[np.mean]})
# Out:
#         기업          영업이익                         매출액
#                      max           min          mean
# 0    대원미디어  7.227984e+09  2.379823e+09  1.673752e+11
# 1  서울바이오시스  2.738493e+10  1.025616e+10  3.894447e+11
# 2  솔브레인홀딩스  1.056940e+11  4.624502e+09  7.490595e+11
# 3    쎄미시스코  3.346492e+09 -7.782689e+09  1.803604e+10
# 4     엔에프씨  6.821097e+09  3.838921e+09  3.007670e+10
# 5      유테크  2.044100e+09 -1.162015e+10  3.655787e+10
# 6     인터지스  1.490524e+10  6.479330e+09  4.792582e+11
# 7      코오롱  2.714480e+11  1.050160e+11  4.368342e+12

# %%
import numpy as np
np_nan_value = np.nan
float_nan_value = float('nan')
print(type(np_nan_value),np_nan_value)
print(type(float_nan_value),float_nan_value)
# Out:
# <class 'float'> nan
# <class 'float'> nan

# %%
s_df = df.iloc[4:8,2:6]
display(s_df,'-'*20)
display(s_df.isnull(),'-'*20)
display(s_df.notnull())
# Out:
#            자산총계          부채총계          자본총계           매출액
# 4  1.446900e+11  3.545975e+10  1.092300e+11  2.662270e+11
# 5           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN
# 7  4.140130e+11  2.530460e+11  1.609670e+11  3.864120e+11
# '--------------------'
#     자산총계   부채총계   자본총계    매출액
# 4  False  False  False  False
# 5   True   True   True   True
# 6   True   True   True   True
# 7  False  False  False  False
# '--------------------'
#     자산총계   부채총계   자본총계    매출액
# 4   True   True   True   True
# 5  False  False  False  False
# 6  False  False  False  False
# 7   True   True   True   True

# %%
display(s_df.isnull().sum(axis=0))
# Out:
# 자산총계    2
# 부채총계    2
# 자본총계    2
# 매출액     2
# dtype: int64

# %%
display(s_df.fillna(0))
# Out:
#            자산총계          부채총계          자본총계           매출액
# 4  1.446900e+11  3.545975e+10  1.092300e+11  2.662270e+11
# 5  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 6  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7  4.140130e+11  2.530460e+11  1.609670e+11  3.864120e+11

# %%
display(s_df.fillna(method='ffill'))
# Out:
#            자산총계          부채총계          자본총계           매출액
# 4  1.446900e+11  3.545975e+10  1.092300e+11  2.662270e+11
# 5  1.446900e+11  3.545975e+10  1.092300e+11  2.662270e+11
# 6  1.446900e+11  3.545975e+10  1.092300e+11  2.662270e+11
# 7  4.140130e+11  2.530460e+11  1.609670e+11  3.864120e+11

# %%
display(s_df.fillna(method='bfill'))
# Out:
#            자산총계          부채총계          자본총계           매출액
# 4  1.446900e+11  3.545975e+10  1.092300e+11  2.662270e+11
# 5  4.140130e+11  2.530460e+11  1.609670e+11  3.864120e+11
# 6  4.140130e+11  2.530460e+11  1.609670e+11  3.864120e+11
# 7  4.140130e+11  2.530460e+11  1.609670e+11  3.864120e+11

# %%
df.drop_duplicates(['기업'],keep='first')
# Out:
#          기업    연도          자산총계          부채총계          자본총계           매출액  \
# 0     대원미디어  2016  9.776068e+10  2.341949e+10  7.434119e+10  9.499312e+10
# 5   서울바이오시스  2016           NaN           NaN           NaN           NaN
# 10  솔브레인홀딩스  2016  8.293910e+11  2.684180e+11  5.609730e+11  7.225210e+11
# 15    쎄미시스코  2016  3.553654e+10  6.320311e+09  2.921623e+10  1.249716e+10
# 20     엔에프씨  2016           NaN           NaN           NaN           NaN
# 25      유테크  2016  6.425440e+10  3.822314e+10  2.603126e+10  2.835045e+10
# 30     인터지스  2016  5.141900e+11  2.933420e+11  2.208480e+11  4.653970e+11
# 35      코오롱  2016  3.332550e+12  2.502330e+12  8.302250e+11  3.936860e+12
#
#             영업이익         당기순이익       부채비율  부채비율>50
# 0   2.379823e+09  4.804263e+08  76.044057     True
# 5            NaN           NaN        NaN    False
# 10  1.051390e+11  7.452030e+10  67.636787     True
# 15  1.025104e+09  1.621465e+09  82.214615     True
# ...

# %%
df.drop_duplicates(['기업'],keep='first').fillna(method='ffill')
# Out:
#          기업    연도          자산총계          부채총계          자본총계           매출액  \
# 0     대원미디어  2016  9.776068e+10  2.341949e+10  7.434119e+10  9.499312e+10
# 5   서울바이오시스  2016  9.776068e+10  2.341949e+10  7.434119e+10  9.499312e+10
# 10  솔브레인홀딩스  2016  8.293910e+11  2.684180e+11  5.609730e+11  7.225210e+11
# 15    쎄미시스코  2016  3.553654e+10  6.320311e+09  2.921623e+10  1.249716e+10
# 20     엔에프씨  2016  3.553654e+10  6.320311e+09  2.921623e+10  1.249716e+10
# 25      유테크  2016  6.425440e+10  3.822314e+10  2.603126e+10  2.835045e+10
# 30     인터지스  2016  5.141900e+11  2.933420e+11  2.208480e+11  4.653970e+11
# 35      코오롱  2016  3.332550e+12  2.502330e+12  8.302250e+11  3.936860e+12
#
#             영업이익         당기순이익       부채비율  부채비율>50
# 0   2.379823e+09  4.804263e+08  76.044057     True
# 5   2.379823e+09  4.804263e+08  76.044057    False
# 10  1.051390e+11  7.452030e+10  67.636787     True
# 15  1.025104e+09  1.621465e+09  82.214615     True
# ...

# %%
df['기업'].unique()
# Out:
# array(['대원미디어', '서울바이오시스', '솔브레인홀딩스', '쎄미시스코', '엔에프씨', '유테크', '인터지스',
#        '코오롱'], dtype=object)

# %%
# 연습
# df에서 대상 연도를 고유하게 추출
df['연도'].unique()
# Out:
# array([2016, 2017, 2018, 2019, 2020])

# %%
# 갯수
df['기업'].nunique()
# Out:
# 8

# %%
df.sort_values(['영업이익','당기순이익'], ascending=False).head(10)
# Out:
#          기업    연도          자산총계          부채총계          자본총계           매출액  \
# 39      코오롱  2020  3.708130e+12  2.849100e+12  8.590350e+11  4.890150e+12
# 38      코오롱  2019  3.618570e+12  2.896670e+12  7.219040e+11  4.284390e+12
# 35      코오롱  2016  3.332550e+12  2.502330e+12  8.302250e+11  3.936860e+12
# 36      코오롱  2017  3.688370e+12  2.785430e+12  9.029420e+11  4.405820e+12
# 11  솔브레인홀딩스  2017  8.959500e+11  2.460910e+11  6.498590e+11  7.755980e+11
# 10  솔브레인홀딩스  2016  8.293910e+11  2.684180e+11  5.609730e+11  7.225210e+11
# 37      코오롱  2018  3.473910e+12  2.644700e+12  8.292060e+11  4.324490e+12
# 9   서울바이오시스  2020  5.828830e+11  3.635450e+11  2.193370e+11  4.312820e+11
# 7   서울바이오시스  2018  4.140130e+11  2.530460e+11  1.609670e+11  3.864120e+11
# 14  솔브레인홀딩스  2020  1.339380e+12  3.032910e+11  1.036090e+12           NaN
#
#             영업이익         당기순이익       부채비율  부채비율>50
# 39  2.714480e+11  1.666080e+11  23.166223    False
# 38  1.343990e+11 -2.222093e+10  19.949944    False
# ...
